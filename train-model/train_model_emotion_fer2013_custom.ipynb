# %% [markdown]
# # Training Model Deteksi Emosi Wajah (FER-2013)
#
# Notebook ini disesuaikan dengan struktur folder project kamu:
#
# ```text
# pak danar/
# ├── 1. FER-2013/
# │   ├── train/
# │   │   ├── angry/
# │   │   ├── disgust/
# │   │   ├── fear/
# │   │   ├── happy/
# │   │   ├── neutral/
# │   │   ├── sad/
# │   │   └── surprise/
# │   └── test/
# │       └── ...
# ```
#
# Output notebook:
# - `models/emotion_model_best.keras`
# - `models/emotion_model_final.keras`
# - `models/class_names.json`
#
# Setelah training selesai, model ini bisa kamu load di `app.py`.

# %%
# Jika belum ada library ini, jalankan cell ini sekali saja
# !pip install tensorflow matplotlib scikit-learn pillow

# %%
from pathlib import Path
import json
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

print("TensorFlow:", tf.__version__)
print("GPU tersedia:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow: 2.21.0
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# GPU tersedia: []

# %%
# Sesuaikan path ini bila posisi notebook berbeda
PROJECT_DIR = Path.cwd()
DATA_DIR = PROJECT_DIR / "1. FER-2013"
TRAIN_DIR = DATA_DIR / "train"
TEST_DIR = DATA_DIR / "test"
MODEL_DIR = PROJECT_DIR / "models"
MODEL_DIR.mkdir(exist_ok=True)

print("PROJECT_DIR =", PROJECT_DIR)
print("TRAIN_DIR   =", TRAIN_DIR)
print("TEST_DIR    =", TEST_DIR)

assert TRAIN_DIR.exists(), f"Folder train tidak ditemukan: {TRAIN_DIR}"
assert TEST_DIR.exists(), f"Folder test tidak ditemukan: {TEST_DIR}"
# Out:
# PROJECT_DIR = d:\Software Development\Projek\pak danar
# TRAIN_DIR   = d:\Software Development\Projek\pak danar\1. FER-2013\train
# TEST_DIR    = d:\Software Development\Projek\pak danar\1. FER-2013\test

# %%
IMG_SIZE = (48, 48)
BATCH_SIZE = 64
SEED = 42
EPOCHS = 20

train_ds = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    labels="inferred",
    label_mode="categorical",
    color_mode="grayscale",
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    shuffle=True,
    seed=SEED,
    validation_split=0.1,
    subset="training",
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    labels="inferred",
    label_mode="categorical",
    color_mode="grayscale",
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    shuffle=True,
    seed=SEED,
    validation_split=0.1,
    subset="validation",
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    TEST_DIR,
    labels="inferred",
    label_mode="categorical",
    color_mode="grayscale",
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    shuffle=False,
)

class_names = train_ds.class_names
num_classes = len(class_names)

print("Class names:", class_names)
print("Jumlah kelas:", num_classes)
# Out:
# Found 28709 files belonging to 7 classes.
# Using 25839 files for training.
# Found 28709 files belonging to 7 classes.
# Using 2870 files for validation.
# Found 7178 files belonging to 7 classes.
# Class names: ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
# Jumlah kelas: 7

# %%
# Simpan nama kelas untuk dipakai di Flask nanti
class_map = {i: name for i, name in enumerate(class_names)}
with open(MODEL_DIR / "class_names.json", "w", encoding="utf-8") as f:
    json.dump(class_map, f, ensure_ascii=False, indent=2)

class_map
# Out:
# {0: 'angry',
#  1: 'disgust',
#  2: 'fear',
#  3: 'happy',
#  4: 'neutral',
#  5: 'sad',
#  6: 'surprise'}

# %%
AUTOTUNE = tf.data.AUTOTUNE

def prepare(ds, training=False):
    ds = ds.cache()
    if training:
        ds = ds.shuffle(1000)
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    return ds

train_ds = prepare(train_ds, training=True)
val_ds = prepare(val_ds)
test_ds = prepare(test_ds)

# %%
# Tampilkan contoh data
plt.figure(figsize=(12, 8))
for images, labels in train_ds.take(1):
    for i in range(12):
        ax = plt.subplot(3, 4, i + 1)
        plt.imshow(tf.squeeze(images[i]), cmap="gray")
        plt.title(class_names[np.argmax(labels[i].numpy())])
        plt.axis("off")
plt.tight_layout()
plt.show()

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.05),
        layers.RandomZoom(0.05),
        layers.RandomTranslation(0.05, 0.05),
    ],
    name="augmentation",
)

model = keras.Sequential(
    [
        layers.Input(shape=(48, 48, 1)),
        data_augmentation,
        layers.Rescaling(1.0 / 255),

        layers.Conv2D(32, 3, padding="same", activation="relu"),
        layers.BatchNormalization(),
        layers.Conv2D(32, 3, padding="same", activation="relu"),
        layers.MaxPooling2D(),
        layers.Dropout(0.25),

        layers.Conv2D(64, 3, padding="same", activation="relu"),
        layers.BatchNormalization(),
        layers.Conv2D(64, 3, padding="same", activation="relu"),
        layers.MaxPooling2D(),
        layers.Dropout(0.25),

        layers.Conv2D(128, 3, padding="same", activation="relu"),
        layers.BatchNormalization(),
        layers.Conv2D(128, 3, padding="same", activation="relu"),
        layers.MaxPooling2D(),
        layers.Dropout(0.3),

        layers.Flatten(),
        layers.Dense(256, activation="relu"),
        layers.BatchNormalization(),
        layers.Dropout(0.4),
        layers.Dense(num_classes, activation="softmax"),
    ]
)

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ augmentation (Sequential)       │ (None, 48, 48, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 48, 48, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 48, 48, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 48, 48, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 48, 48, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 24, 24, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 24, 24, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 24, 24, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 12, 12, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 12, 12, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 12, 12, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4608)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │         1,799 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,470,055 (5.61 MB)
#  Trainable params: 1,469,095 (5.60 MB)
#  Non-trainable params: 960 (3.75 KB)

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath=str(MODEL_DIR / "emotion_model_best.keras"),
        monitor="val_accuracy",
        save_best_only=True,
        mode="max",
        verbose=1,
    ),
    keras.callbacks.EarlyStopping(
        monitor="val_accuracy",
        patience=5,
        restore_best_weights=True,
        verbose=1,
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=2,
        min_lr=1e-6,
        verbose=1,
    ),
]

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks,
)
# Out:
# Epoch 1/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 0s 765ms/step - accuracy: 0.2324 - loss: 2.1148
# Epoch 1: val_accuracy improved from None to 0.30767, saving model to d:\Software Development\Projek\pak danar\models\emotion_model_best.keras
#
# Epoch 1: finished saving model to d:\Software Development\Projek\pak danar\models\emotion_model_best.keras
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 344s 826ms/step - accuracy: 0.2740 - loss: 1.9063 - val_accuracy: 0.3077 - val_loss: 1.7687 - learning_rate: 0.0010
# Epoch 2/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 0s 734ms/step - accuracy: 0.3779 - loss: 1.6161
# Epoch 2: val_accuracy improved from 0.30767 to 0.46620, saving model to d:\Software Development\Projek\pak danar\models\emotion_model_best.keras
#
# Epoch 2: finished saving model to d:\Software Development\Projek\pak danar\models\emotion_model_best.keras
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 304s 751ms/step - accuracy: 0.4013 - loss: 1.5590 - val_accuracy: 0.4662 - val_loss: 1.3841 - learning_rate: 0.0010
# Epoch 3/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 0s 662ms/step - accuracy: 0.4461 - loss: 1.4376
# Epoch 3: val_accuracy improved from 0.46620 to 0.49617, saving model to d:\Software Development\Projek\pak danar\models\emotion_model_best.keras
#
# Epoch 3: finished saving model to d:\Software Development\Projek\pak danar\models\emotion_model_best.keras
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 274s 679ms/step - accuracy: 0.4595 - loss: 1.4069 - val_accuracy: 0.4962 - val_loss: 1.3012 - learning_rate: 0.0010
# Epoch 4/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 0s 661ms/step - accuracy: 0.4807 - loss: 1.3529
# Epoch 4: val_accuracy improved from 0.49617 to 0.50070, saving model to d:\Software Development\Projek\pak danar\models\emotion_model_best.keras
#
# Epoch 4: finished saving model to d:\Software Development\Projek\pak danar\models\emotion_model_best.keras
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 274s 678ms/step - accuracy: 0.4920 - loss: 1.3307 - val_accuracy: 0.5007 - val_loss: 1.3042 - learning_rate: 0.0010
# Epoch 5/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 0s 642ms/step - accuracy: 0.5052 - loss: 1.2919
# Epoch 5: val_accuracy improved from 0.50070 to 0.54146, saving model to d:\Software Development\Projek\pak danar\models\emotion_model_best.keras
#
# Epoch 5: finished saving model to d:\Software Development\Projek\pak danar\models\emotion_model_best.keras
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 265s 657ms/step - accuracy: 0.5100 - loss: 1.2844 - val_accuracy: 0.5415 - val_loss: 1.2159 - learning_rate: 0.0010
# Epoch 6/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 0s 679ms/step - accuracy: 0.5290 - loss: 1.2428
# Epoch 6: val_accuracy did not improve from 0.54146
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 280s 694ms/step - accuracy: 0.5302 - loss: 1.2357 - val_accuracy: 0.5362 - val_loss: 1.1783 - learning_rate: 0.0010
# Epoch 7/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 0s 631ms/step - accuracy: 0.5391 - loss: 1.2088
# Epoch 7: val_accuracy improved from 0.54146 to 0.54878, saving model to d:\Software Development\Projek\pak danar\models\emotion_model_best.keras
#
# Epoch 7: finished saving model to d:\Software Development\Projek\pak danar\models\emotion_model_best.keras
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 262s 648ms/step - accuracy: 0.5400 - loss: 1.2117 - val_accuracy: 0.5488 - val_loss: 1.1997 - learning_rate: 0.0010
# Epoch 8/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 0s 613ms/step - accuracy: 0.5520 - loss: 1.1862
# Epoch 8: val_accuracy improved from 0.54878 to 0.57352, saving model to d:\Software Development\Projek\pak danar\models\emotion_model_best.keras
#
# Epoch 8: finished saving model to d:\Software Development\Projek\pak danar\models\emotion_model_best.keras
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 255s 630ms/step - accuracy: 0.5536 - loss: 1.1834 - val_accuracy: 0.5735 - val_loss: 1.1421 - learning_rate: 0.0010
# Epoch 9/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 0s 649ms/step - accuracy: 0.5590 - loss: 1.1681
# Epoch 9: val_accuracy did not improve from 0.57352
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 270s 669ms/step - accuracy: 0.5629 - loss: 1.1609 - val_accuracy: 0.5436 - val_loss: 1.2229 - learning_rate: 0.0010
# Epoch 10/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 0s 638ms/step - accuracy: 0.5700 - loss: 1.1405
# Epoch 10: val_accuracy did not improve from 0.57352
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 264s 653ms/step - accuracy: 0.5691 - loss: 1.1446 - val_accuracy: 0.5714 - val_loss: 1.1318 - learning_rate: 0.0010
# Epoch 11/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 0s 664ms/step - accuracy: 0.5774 - loss: 1.1211
# Epoch 11: val_accuracy did not improve from 0.57352
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 275s 682ms/step - accuracy: 0.5759 - loss: 1.1231 - val_accuracy: 0.5383 - val_loss: 1.1844 - learning_rate: 0.0010
# Epoch 12/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 0s 585ms/step - accuracy: 0.5823 - loss: 1.1045
# Epoch 12: val_accuracy did not improve from 0.57352
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 242s 600ms/step - accuracy: 0.5815 - loss: 1.1119 - val_accuracy: 0.5519 - val_loss: 1.1786 - learning_rate: 0.0010
# Epoch 13/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 0s 565ms/step - accuracy: 0.5991 - loss: 1.0696
# Epoch 13: val_accuracy improved from 0.57352 to 0.61394, saving model to d:\Software Development\Projek\pak danar\models\emotion_model_best.keras
#
# Epoch 13: finished saving model to d:\Software Development\Projek\pak danar\models\emotion_model_best.keras
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 234s 580ms/step - accuracy: 0.6012 - loss: 1.0728 - val_accuracy: 0.6139 - val_loss: 1.0175 - learning_rate: 5.0000e-04
# Epoch 14/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 0s 563ms/step - accuracy: 0.6055 - loss: 1.0430
# Epoch 14: val_accuracy did not improve from 0.61394
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 233s 577ms/step - accuracy: 0.6044 - loss: 1.0512 - val_accuracy: 0.5885 - val_loss: 1.1076 - learning_rate: 5.0000e-04
# Epoch 15/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 0s 581ms/step - accuracy: 0.6129 - loss: 1.0281
# Epoch 15: val_accuracy did not improve from 0.61394
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 241s 595ms/step - accuracy: 0.6071 - loss: 1.0433 - val_accuracy: 0.5969 - val_loss: 1.0585 - learning_rate: 5.0000e-04
# Epoch 16/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 0s 604ms/step - accuracy: 0.6217 - loss: 1.0149
# Epoch 16: val_accuracy did not improve from 0.61394
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 250s 619ms/step - accuracy: 0.6195 - loss: 1.0214 - val_accuracy: 0.6125 - val_loss: 1.0201 - learning_rate: 2.5000e-04
# Epoch 17/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 0s 564ms/step - accuracy: 0.6236 - loss: 1.0094
# Epoch 17: val_accuracy did not improve from 0.61394
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 233s 578ms/step - accuracy: 0.6248 - loss: 1.0052 - val_accuracy: 0.6077 - val_loss: 1.0373 - learning_rate: 2.5000e-04
# Epoch 18/20
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 0s 580ms/step - accuracy: 0.6256 - loss: 0.9898
# Epoch 18: val_accuracy did not improve from 0.61394
# 404/404 ━━━━━━━━━━━━━━━━━━━━ 240s 595ms/step - accuracy: 0.6275 - loss: 0.9889 - val_accuracy: 0.6049 - val_loss: 1.0321 - learning_rate: 1.2500e-04
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 13.

# %%
model.save(MODEL_DIR / "emotion_model_final.keras")
print("Model final disimpan ke:", MODEL_DIR / "emotion_model_final.keras")
# Out:
# Model final disimpan ke: d:\Software Development\Projek\pak danar\models\emotion_model_final.keras

# %%
# Plot hasil training
history_dict = history.history

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history_dict["accuracy"], label="train_acc")
plt.plot(history_dict["val_accuracy"], label="val_acc")
plt.title("Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history_dict["loss"], label="train_loss")
plt.plot(history_dict["val_loss"], label="val_loss")
plt.title("Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Evaluasi di test set
best_model = keras.models.load_model(MODEL_DIR / "emotion_model_best.keras")
test_loss, test_acc = best_model.evaluate(test_ds)
print(f"Test loss     : {test_loss:.4f}")
print(f"Test accuracy : {test_acc:.4f}")
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 37s 315ms/step - accuracy: 0.6084 - loss: 1.0306
# Test loss     : 1.0306
# Test accuracy : 0.6084

# %%
# Contoh prediksi 1 batch
images, labels = next(iter(test_ds))
preds = best_model.predict(images)

plt.figure(figsize=(14, 10))
for i in range(12):
    ax = plt.subplot(3, 4, i + 1)
    plt.imshow(tf.squeeze(images[i]), cmap="gray")
    true_label = class_names[np.argmax(labels[i].numpy())]
    pred_label = class_names[np.argmax(preds[i])]
    conf = float(np.max(preds[i])) * 100
    plt.title(f"True: {true_label}\nPred: {pred_label} ({conf:.1f}%)")
    plt.axis("off")
plt.tight_layout()
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step

# %% [markdown]
# ## Langkah berikutnya
#
# Setelah file model jadi, kamu bisa pakai di `app.py` seperti ini secara garis besar:
#
# ```python
# model = keras.models.load_model("models/emotion_model_best.keras")
# with open("models/class_names.json", "r", encoding="utf-8") as f:
#     class_map = json.load(f)
# ```
#
# Lalu saat user upload gambar:
# 1. baca gambar
# 2. ubah ke grayscale
# 3. resize ke `48x48`
# 4. normalisasi
# 5. `model.predict()`
# 6. ambil label emosi tertinggi
